# %%
import torch

from ultralytics import YOLO
model = YOLO().load_state_dict(torch.load("./yolo.pth",map_location ='cpu'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 4
#       1 import torch
#       3 from ultralytics import YOLO
# ----> 4 model = YOLO().load_state_dict(torch.load("./yolo.pth"))
#
# File c:\Users\afaru\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File c:\Users\afaru\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
# ...

# %%
path = "C:/Users/afaru/Downloads/Telegram Desktop/photo_2024-04-20_14-46-54.jpg"

# %%
dir(model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_backward_pre_hooks',
#  '_buffers',
#  '_call_impl',
#  '_check_is_pytorch_model',
#  '_forward_hooks',
#  '_forward_hooks_with_kwargs',
#  '_forward_pre_hooks',
#  '_forward_pre_hooks_with_kwargs',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
#  '_get_hub_session',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load',
#  '_load_from_state_dict',
#  '_load_state_dict_post_hooks',
#  '_load_state_dict_pre_hooks',
# ...
